# %%
## Consumer Complaint Classification Pipeline

import os
import pandas as pd
import numpy as np
import torch
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import accuracy_score, precision_recall_fscore_support, classification_report, roc_auc_score, roc_curve
from sklearn.preprocessing import label_binarize 
from transformers import (
    AutoTokenizer, 
    AutoModelForSequenceClassification,
    TrainingArguments, 
    Trainer,
    EarlyStoppingCallback
)
from peft import get_peft_model, LoraModel ,LoraConfig, TaskType, PrefixEncoder, PrefixTuningConfig, IA3Config, IA3Model
from torch.utils.data import Dataset
import wandb
import random
import matplotlib.pyplot as plt
import seaborn as sns
from collections import defaultdict
import shutil

# =====================================
# W&B AUTHENTICATION
# =====================================

# Insert your W&B API key here
WANDB_API_KEY = "71205bbb0d873d20bc29f836d86ca04ce650833e"  # Replace with your actual API key

# Login to W&B
wandb.login(key=WANDB_API_KEY)

# =====================================
# CONFIGURATION & SETUP
# =====================================

class Config:
    # Model Configuration - Choose appropriate pre-trained model
    MODEL_NAME = "distilbert-base-uncased"  # Efficient for English text classification
    MAX_LENGTH = 512
    
    # Training Configuration (Fixed hyperparameters - no tuning)
    LEARNING_RATE = 2e-5  # Lower learning rate as suggested by professor
    BATCH_SIZE = 16
    NUM_EPOCHS = 10  # More epochs to observe learning curves and plateaus
    WARMUP_STEPS = 500
    WEIGHT_DECAY = 0.01
    
    # Statistical Robustness Configuration
    NUM_ITERATIONS = 5  # Different train/val/test splits
    SAMPLE_SIZE_PER_CLASS = 2500  # Balanced sampling per class
    
    # Monitoring & Logging
    LOGGING_STEPS = 50  # Frequent logging for real-time metrics
    EVAL_STEPS = 100    # Evaluate every 100 steps
    SAVE_STEPS = 200
    
    # Paths
    DATA_PATH = './data/complaints.csv'  # make sure the file exists here
    OUTPUT_DIR = './outputs'  # local directory you can write to
    
    # Space Optimization Configuration
    SAVE_MODELS = False  # Don't save individual models to preserve space
    SAVE_ONLY_BEST_MODEL = True  # Save only the best performing model

    # W&B Configuration
    WANDB_PROJECT = "consumer-complaints-robustness-with-lora"
    WANDB_ENTITY = None  # Set your W&B username if needed

def set_seed(seed=42):
    """Set seed for reproducibility across all iterations"""
    random.seed(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    
def setup_wandb(iteration):
    """Initialize W&B for tracking real-time metrics"""
    wandb.init(
        project=Config.WANDB_PROJECT,
        entity=Config.WANDB_ENTITY,
        name=f"iteration_{iteration + 1}",
        config={
            "model": Config.MODEL_NAME,
            "learning_rate": Config.LEARNING_RATE,
            "batch_size": Config.BATCH_SIZE,
            "epochs": Config.NUM_EPOCHS,
            "max_length": Config.MAX_LENGTH,
            "iteration": iteration + 1,
            "sample_size_per_class": Config.SAMPLE_SIZE_PER_CLASS
        },
        reinit=True,
        tags=["statistical_robustness", "transformer", "classification"]
    )

# =====================================
# DATASET PREPARATION
# =====================================

class ComplaintDataset(Dataset):
    """Custom dataset for consumer complaints"""
    
    def __init__(self, texts, labels, tokenizer, max_length=512):
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_length = max_length
    
    def __len__(self):
        return len(self.texts)
    
    def __getitem__(self, idx):
        text = str(self.texts[idx])
        encoding = self.tokenizer(
            text,
            truncation=True,
            padding='max_length',
            max_length=self.max_length,
            return_tensors='pt'
        )
        
        return {
            'input_ids': encoding['input_ids'].flatten(),
            'attention_mask': encoding['attention_mask'].flatten(),
            'labels': torch.tensor(self.labels[idx], dtype=torch.long)
        }

def load_and_prepare_data():
    """Load and prepare the consumer complaints dataset"""
    print("📊 Loading and preparing dataset...")
    
    # Load data
    df = pd.read_csv(Config.DATA_PATH)
    if 'Unnamed: 0' in df.columns:
        df = df.drop(columns=['Unnamed: 0'])
    
    print(f"   Original dataset size: {len(df)}")
    print(f"   Original class distribution:")
    print(df['product_5'].value_counts())
    
    # Balance dataset by sampling from each class
    df_balanced = df.groupby("product_5").sample(
        n=Config.SAMPLE_SIZE_PER_CLASS, 
        random_state=42,
        replace=False  # Ensure no duplicates
    ).reset_index(drop=True)
    
    # Encode labels
    label_encoder = LabelEncoder()
    encoded_labels = label_encoder.fit_transform(df_balanced['product_5'])
    
    # Create label mapping
    label_mapping = {i: label for i, label in enumerate(label_encoder.classes_)}
    
    print(f"✅ Balanced dataset prepared: {len(df_balanced)} samples")
    print(f"📋 Classes ({len(label_mapping)}): {list(label_mapping.values())}")
    print(f"📋 Samples per class: {Config.SAMPLE_SIZE_PER_CLASS}")
    
    return df_balanced['narrative'].values, encoded_labels, label_mapping, label_encoder

def create_stratified_splits(texts, labels, iteration):
    """Create stratified train/validation/test splits for statistical robustness"""
    
    # Use different random state for each iteration to ensure different splits
    random_state = 42 + iteration * 10
    
    # First split: 70% train, 30% temp
    train_texts, temp_texts, train_labels, temp_labels = train_test_split(
        texts, labels, 
        test_size=0.3, 
        random_state=random_state, 
        stratify=labels
    )
    
    # Second split: 15% validation, 15% test (from the 30% temp)
    val_texts, test_texts, val_labels, test_labels = train_test_split(
        temp_texts, temp_labels,
        test_size=0.5,  # 50% of 30% = 15% of total
        random_state=random_state,
        stratify=temp_labels
    )
    
    print(f"🔄 Split {iteration + 1}: Train={len(train_texts)}, Val={len(val_texts)}, Test={len(test_texts)}")
    
    # Verify class distribution is maintained
    unique_train, counts_train = np.unique(train_labels, return_counts=True)
    unique_val, counts_val = np.unique(val_labels, return_counts=True)
    unique_test, counts_test = np.unique(test_labels, return_counts=True)
    
    print(f"   Train classes: {dict(zip(unique_train, counts_train))}")
    print(f"   Val classes: {dict(zip(unique_val, counts_val))}")
    print(f"   Test classes: {dict(zip(unique_test, counts_test))}")
    
    return (train_texts, train_labels), (val_texts, val_labels), (test_texts, test_labels)

# =====================================
# MODEL & TRAINING SETUP
# =====================================

def setup_model_and_tokenizer(num_labels, model_type="distilbert", peft_type="none"):
    """Initialize model, tokenizer, and wrap with PEFT if specified"""
    print(f"🤖 Loading model: {Config.MODEL_NAME}")
    
    tokenizer = AutoTokenizer.from_pretrained(Config.MODEL_NAME)
    model = AutoModelForSequenceClassification.from_pretrained(
        Config.MODEL_NAME,
        num_labels=num_labels,
        problem_type="single_label_classification"
    )
    
    # Add pad token if missing
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token
        model.config.pad_token_id = model.config.eos_token_id

    # Determine target modules for PEFT
    if peft_type.lower() == "lora":
        if model_type == "distilbert":
            target_modules = ["q_lin", "v_lin"]
        elif model_type == "roberta":
            target_modules = ["q", "v"]
        else:
            raise ValueError(f"Unsupported model_type for LoRA: {model_type}")

        lora_config = LoraConfig(
            task_type=TaskType.SEQ_CLS,
            r=8,
            lora_alpha=16,
            target_modules=target_modules,
            lora_dropout=0.1,
            bias="none"
        )
        model = get_peft_model(model, lora_config)

    elif peft_type.lower() == "prefix":
        prefix_config = PrefixTuningConfig(
            peft_type="PREFIX_TUNING",
            task_type="SEQ_CLS",
            num_virtual_tokens=20,
            token_dim=model.config.hidden_size,
            num_attention_heads=model.config.num_attention_heads,
            num_layers=model.config.num_hidden_layers,
        )
        model = get_peft_model(model, prefix_config)

    elif peft_type.lower() == "ia3":
        ia3_config = IA3Config(
            peft_type="IA3",
            task_type="SEQ_CLS",
            target_modules=["k", "v"],
            feedforward_modules=["intermediate.dense"]
        )
        model = get_peft_model(model, ia3_config)

    else:
        print("⚠️ No PEFT applied. Using full fine-tuning.")

    return model, tokenizer

def compute_metrics(eval_pred):
    """Compute comprehensive metrics for evaluation"""
    predictions, labels = eval_pred
    predictions = np.argmax(predictions, axis=1)
    
    # Calculate metrics
    precision, recall, f1, _ = precision_recall_fscore_support(
        labels, predictions, average='weighted', zero_division=0
    )
    accuracy = accuracy_score(labels, predictions)
    
    # Per-class metrics for detailed analysis
    precision_per_class, recall_per_class, f1_per_class, _ = precision_recall_fscore_support(
        labels, predictions, average=None, zero_division=0
    )
    
    return {
        'accuracy': accuracy,
        'f1': f1,
        'precision': precision,
        'recall': recall,
        'f1_per_class_mean': np.mean(f1_per_class),
        'precision_per_class_mean': np.mean(precision_per_class),
        'recall_per_class_mean': np.mean(recall_per_class)
    }

# =====================================
# TRAINING PIPELINE
# =====================================

def train_single_iteration(iteration, train_data, val_data, test_data, 
                         model, tokenizer, label_mapping):
    """Train model for a single iteration and evaluate performance"""
    
    print(f"\n🚀 Starting training for iteration {iteration + 1}...")
    
    # Initialize W&B for this iteration
    setup_wandb(iteration)
    
    # Create datasets from data tuples
    train_dataset = ComplaintDataset(*train_data, tokenizer, Config.MAX_LENGTH)
    val_dataset = ComplaintDataset(*val_data, tokenizer, Config.MAX_LENGTH)
    test_dataset = ComplaintDataset(*test_data, tokenizer, Config.MAX_LENGTH)
    
    # Define iteration-specific paths - use temporary directory
    iter_dir = f"/tmp/iteration_{iteration + 1}"  # Use /tmp instead of output dir
    
    # Setup training arguments with minimal disk usage
    training_args = TrainingArguments(
        # Basic configuration
        output_dir=iter_dir,
        num_train_epochs=Config.NUM_EPOCHS,
        per_device_train_batch_size=Config.BATCH_SIZE,
        per_device_eval_batch_size=Config.BATCH_SIZE,
        
        # Optimization parameters
        learning_rate=Config.LEARNING_RATE,
        weight_decay=Config.WEIGHT_DECAY,
        warmup_steps=Config.WARMUP_STEPS,
        
        # Evaluation and saving - MINIMAL SAVING
        eval_strategy="steps",
        save_strategy="steps",  # Don't save checkpoints during training
        eval_steps=Config.EVAL_STEPS,
        load_best_model_at_end=True,
        metric_for_best_model="eval_accuracy",
        greater_is_better=True,
        save_total_limit=1,  # Keep only 1 checkpoint
        
        # Logging
        logging_dir=None,  # Don't save logs to disk
        logging_steps=Config.LOGGING_STEPS,
        logging_first_step=True,
        report_to="wandb",
        run_name=f"iteration_{iteration + 1}",
        
        # System settings
        dataloader_num_workers=0,
        fp16=torch.cuda.is_available(),
        seed=42 + iteration,
    )
    
    # Initialize trainer with early stopping
    trainer = Trainer(
        model=model,
        args=training_args,
        train_dataset=train_dataset,
        eval_dataset=val_dataset,
        compute_metrics=compute_metrics,
        callbacks=[EarlyStoppingCallback(early_stopping_patience=3, early_stopping_threshold=0.001)]
    )
    
    # Train and evaluate
    print(f"   Training with {len(train_dataset)} samples...")
    train_result = trainer.train()
    test_results = trainer.evaluate(test_dataset, metric_key_prefix="test")
    
    # Log training metrics to W&B
    wandb.log({
        "train_runtime": train_result.metrics.get("train_runtime", 0),
        "train_samples_per_second": train_result.metrics.get("train_samples_per_second", 0),
        "total_train_steps": train_result.global_step,
        "iteration": iteration + 1
    })
    
    # Generate predictions and classification report
    predictions = trainer.predict(test_dataset)
    y_pred = np.argmax(predictions.predictions, axis=1)
    class_names = [label_mapping[i] for i in range(len(label_mapping))]
    report = classification_report(
        test_data[1], y_pred, target_names=class_names, output_dict=True, zero_division=0
    )
    
    # Perform error analysis
    error_analysis = perform_error_analysis(
        y_pred, test_data[1], test_data[0], class_names, iteration
    )

    # Log test results
    wandb.log({
        "test_accuracy": test_results["test_accuracy"],
        "test_f1": test_results["test_f1"],
        "test_precision": test_results["test_precision"],
        "test_recall": test_results["test_recall"]
    })
    
    # Log per-class metrics
    for i, class_name in enumerate(class_names):
        if str(i) in report:
            class_key = class_name.lower().replace(' ', '_')
            wandb.log({
                f"test_{class_key}_f1": report[str(i)]['f1-score'],
                f"test_{class_key}_precision": report[str(i)]['precision'],
                f"test_{class_key}_recall": report[str(i)]['recall']
            })
    
    # Log additional error analysis metrics to W&B
    wandb.log({
        "error_rate": error_analysis["error_rate"],
        "top_error_count": error_analysis["common_errors"][0][1] if error_analysis["common_errors"] else 0,
    })
    
    # Print results
    print(f"📈 Results: Acc={test_results['test_accuracy']:.4f}, F1={test_results['test_f1']:.4f}")
    
    # Clean up temporary directory
    import shutil
    if os.path.exists(iter_dir):
        shutil.rmtree(iter_dir)
        print(f"🗑️  Cleaned up temporary files for iteration {iteration + 1}")
    
    wandb.finish()
    
    # Return key metrics (without model path since we're not saving)
    return {
        'accuracy': test_results["test_accuracy"],
        'f1': test_results["test_f1"],
        'precision': test_results["test_precision"],
        'recall': test_results["test_recall"],
        'classification_report': report,
        'train_steps': train_result.global_step,
        'iteration': iteration + 1,
        'error_analysis': error_analysis  # Add error analysis to results
    }


# =====================================
# MAIN PIPELINE EXECUTION
# =====================================

def create_results_summary(all_results):
    """Create comprehensive results summary"""
    
    # Extract metrics
    accuracies = [r['accuracy'] for r in all_results]
    f1_scores = [r['f1'] for r in all_results]
    precisions = [r['precision'] for r in all_results]
    recalls = [r['recall'] for r in all_results]
    
    # Calculate statistics
    results_summary = {
        'accuracy': {
            'mean': np.mean(accuracies),
            'std': np.std(accuracies),
            'min': np.min(accuracies),
            'max': np.max(accuracies),
            'values': accuracies
        },
        'f1': {
            'mean': np.mean(f1_scores),
            'std': np.std(f1_scores),
            'min': np.min(f1_scores),
            'max': np.max(f1_scores),
            'values': f1_scores
        },
        'precision': {
            'mean': np.mean(precisions),
            'std': np.std(precisions),
            'min': np.min(precisions),
            'max': np.max(precisions),
            'values': precisions
        },
        'recall': {
            'mean': np.mean(recalls),
            'std': np.std(recalls),
            'min': np.min(recalls),
            'max': np.max(recalls),
            'values': recalls
        }
    }
    
    return results_summary

def plot_results_distribution(results_summary):
    """Create visualization of results distribution"""
    
    fig, axes = plt.subplots(2, 2, figsize=(12, 10))
    fig.suptitle('Statistical Robustness Results Distribution', fontsize=16)
    
    metrics = ['accuracy', 'f1', 'precision', 'recall']
    colors = ['blue', 'green', 'orange', 'red']
    
    for i, (metric, color) in enumerate(zip(metrics, colors)):
        ax = axes[i//2, i%2]
        values = results_summary[metric]['values']
        
        # Box plot
        ax.boxplot(values, patch_artist=True, 
                  boxprops=dict(facecolor=color, alpha=0.3))
        ax.scatter(range(1, len(values)+1), values, 
                  color=color, alpha=0.7, s=50)
        
        # Add mean line
        mean_val = results_summary[metric]['mean']
        ax.axhline(y=mean_val, color=color, linestyle='--', alpha=0.8)
        
        ax.set_title(f'{metric.capitalize()} Distribution')
        ax.set_ylabel(metric.capitalize())
        ax.set_xlabel('Iteration')
        ax.grid(True, alpha=0.3)
        
        # Add statistics text
        std_val = results_summary[metric]['std']
        ax.text(0.02, 0.98, f'Mean: {mean_val:.4f}\nStd: {std_val:.4f}', 
               transform=ax.transAxes, verticalalignment='top',
               bbox=dict(boxstyle='round', facecolor='white', alpha=0.8))
    
    plt.tight_layout()
    plt.savefig(f'{Config.OUTPUT_DIR}/results_distribution.png', dpi=300, bbox_inches='tight')
    plt.show()

# Add new function to track and save only the best model
def track_best_model(all_results, iteration, model, tokenizer):
    """Track and save only the best performing model"""
    
    current_accuracy = all_results[-1]['accuracy']
    
    # Check if this is the best model so far
    if iteration == 0:  # First iteration
        best_accuracy = current_accuracy
        is_best = True
    else:
        best_accuracy = max([r['accuracy'] for r in all_results[:-1]])
        is_best = current_accuracy > best_accuracy
    
    if is_best and Config.SAVE_ONLY_BEST_MODEL:
        # Remove previous best model if exists
        best_model_path = f"{Config.OUTPUT_DIR}/best_model_overall"
        if os.path.exists(best_model_path):
            shutil.rmtree(best_model_path)
        
        # Save current best model
        os.makedirs(best_model_path, exist_ok=True)
        model.save_pretrained(best_model_path)
        tokenizer.save_pretrained(best_model_path)
        
        print(f"💾 New best model saved! Accuracy: {current_accuracy:.4f}")
        
        # Save best model info
        best_info = {
            'iteration': iteration + 1,
            'accuracy': current_accuracy,
            'model_path': best_model_path
        }
        
        import json
        with open(f"{Config.OUTPUT_DIR}/best_model_info.json", 'w') as f:
            json.dump(best_info, f, indent=2)
    
    return is_best

# =====================================
# ERROR ANALYSIS
# =====================================

def perform_error_analysis(predictions, true_labels, texts, class_names, iteration):
    """
    Perform comprehensive error analysis on model predictions
    
    Args:
        predictions: Model predictions (class indices)
        true_labels: Ground truth labels
        texts: Original text samples
        class_names: List of class names
        iteration: Current iteration number
    
    Returns:
        error_analysis_results: Dictionary with error analysis metrics
    """
    print(f"\n🔍 ERROR ANALYSIS FOR ITERATION {iteration + 1}")
    print("-" * 40)
    
    # Create confusion matrix
    from sklearn.metrics import confusion_matrix
    import seaborn as sns
    
    cm = confusion_matrix(true_labels, predictions)
    
    # Plot and save confusion matrix
    plt.figure(figsize=(10, 8))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues', 
                xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title(f'Confusion Matrix - Iteration {iteration + 1}')
    plt.tight_layout()
    
    # Save the confusion matrix
    os.makedirs(f"{Config.OUTPUT_DIR}/error_analysis", exist_ok=True)
    plt.savefig(f"{Config.OUTPUT_DIR}/error_analysis/confusion_matrix_iter_{iteration + 1}.png", 
                dpi=300, bbox_inches='tight')
    
    # Find misclassified examples
    misclassified_indices = np.where(predictions != true_labels)[0]
    correct_indices = np.where(predictions == true_labels)[0]
    
    accuracy = len(correct_indices) / (len(correct_indices) + len(misclassified_indices))
    
    print(f"   Total test samples: {len(true_labels)}")
    print(f"   Correctly classified: {len(correct_indices)} ({accuracy:.2%})")
    print(f"   Misclassified: {len(misclassified_indices)} ({1-accuracy:.2%})")
    
    # Extract most common misclassifications
    error_pairs = []
    for idx in misclassified_indices:
        true_class = class_names[true_labels[idx]]
        pred_class = class_names[predictions[idx]]
        error_pairs.append((true_class, pred_class))
    
    # Count frequency of each error type
    error_counts = {}
    for true_class, pred_class in error_pairs:
        error_key = f"{true_class} → {pred_class}"
        error_counts[error_key] = error_counts.get(error_key, 0) + 1
    
    # Sort by frequency
    common_errors = sorted(error_counts.items(), key=lambda x: x[1], reverse=True)
    
    print("\n   Most common misclassifications:")
    for error_type, count in common_errors[:5]:  # Show top 5 errors
        print(f"   - {error_type}: {count} samples ({count/len(misclassified_indices):.1%} of errors)")
    
    # Extract some example misclassifications
    misclassified_samples = []
    if len(misclassified_indices) > 0:
        # Get a sample of misclassified examples (max 20)
        sample_size = min(20, len(misclassified_indices))
        sample_indices = np.random.choice(misclassified_indices, sample_size, replace=False)
        
        for idx in sample_indices:
            misclassified_samples.append({
                'text': texts[idx][:100] + "..." if len(texts[idx]) > 100 else texts[idx],
                'true_label': class_names[true_labels[idx]],
                'pred_label': class_names[predictions[idx]]
            })
    
    # Class-wise error analysis
    class_metrics = {}
    for i, class_name in enumerate(class_names):
        # Find indices where true label is this class
        class_indices = np.where(true_labels == i)[0]
        if len(class_indices) == 0:
            continue
            
        # Calculate accuracy for this class
        class_correct = np.sum(predictions[class_indices] == true_labels[class_indices])
        class_accuracy = class_correct / len(class_indices)
        
        # Find most common incorrect predictions for this class
        class_errors = {}
        for idx in class_indices:
            if predictions[idx] != true_labels[idx]:
                pred_class = class_names[predictions[idx]]
                class_errors[pred_class] = class_errors.get(pred_class, 0) + 1
        
        # Sort errors by frequency
        common_class_errors = sorted(class_errors.items(), key=lambda x: x[1], reverse=True)
        
        class_metrics[class_name] = {
            'accuracy': class_accuracy,
            'total_samples': len(class_indices),
            'common_errors': common_class_errors[:3]  # Top 3 errors
        }
    
    # Compile all error analysis results
    error_analysis_results = {
        'confusion_matrix': cm,
        'accuracy': accuracy,
        'error_rate': 1 - accuracy,
        'common_errors': common_errors[:10],  # Top 10 most common errors
        'misclassified_samples': misclassified_samples,
        'class_metrics': class_metrics
    }
    
    # Create error analysis report
    report_path = f"{Config.OUTPUT_DIR}/error_analysis/report_iter_{iteration + 1}.txt"
    with open(report_path, 'w') as f:
        f.write(f"ERROR ANALYSIS REPORT - ITERATION {iteration + 1}\n")
        f.write("=" * 50 + "\n\n")
        
        f.write(f"Overall Accuracy: {accuracy:.4f}\n")
        f.write(f"Error Rate: {1-accuracy:.4f}\n\n")
        
        f.write("MOST COMMON MISCLASSIFICATIONS:\n")
        f.write("-" * 30 + "\n")
        for error_type, count in common_errors[:10]:
            f.write(f"{error_type}: {count} samples ({count/len(misclassified_indices):.1%} of errors)\n")
        
        f.write("\nCLASS-WISE PERFORMANCE:\n")
        f.write("-" * 30 + "\n")
        for class_name, metrics in class_metrics.items():
            f.write(f"\n{class_name}:\n")
            f.write(f"  Accuracy: {metrics['accuracy']:.4f}\n")
            f.write(f"  Total Samples: {metrics['total_samples']}\n")
            if metrics['common_errors']:
                f.write("  Common errors:\n")
                for error_class, count in metrics['common_errors']:
                    f.write(f"    - Confused as {error_class}: {count} times\n")
    
    print(f"   Error analysis report saved to {report_path}")
    
    return error_analysis_results

# Function to aggregate error analysis across iterations
def aggregate_error_analysis(all_error_analyses, label_mapping):
    """
    Aggregate error analyses across multiple iterations
    """
    print("\n📊 AGGREGATING ERROR ANALYSIS ACROSS ITERATIONS")
    print("-" * 60)
    
    # Aggregate common errors across iterations
    all_common_errors = defaultdict(int)
    for analysis in all_error_analyses:
        for error_pair, count in analysis['common_errors']:
            all_common_errors[error_pair] += count
    
    # Sort aggregated errors
    aggregated_common_errors = sorted(all_common_errors.items(), key=lambda x: x[1], reverse=True)
    
    # Aggregate class-wise metrics
    class_accuracies = defaultdict(list)
    for analysis in all_error_analyses:
        for class_name, metrics in analysis['class_metrics'].items():
            class_accuracies[class_name].append(metrics['accuracy'])
    
    # Calculate mean and standard deviation of class accuracies
    class_metrics_summary = {}
    for class_name, accuracies in class_accuracies.items():
        class_metrics_summary[class_name] = {
            'mean_accuracy': np.mean(accuracies),
            'std_accuracy': np.std(accuracies),
            'min_accuracy': np.min(accuracies),
            'max_accuracy': np.max(accuracies)
        }
    
    # Print summary
    print("\nMOST CHALLENGING CLASSIFICATION PAIRS (AGGREGATED):")
    for error_pair, total_count in aggregated_common_errors[:5]:
        print(f"   - {error_pair}: {total_count} total errors")
    
    print("\nCLASS-WISE ACCURACY SUMMARY:")
    for class_name, metrics in sorted(class_metrics_summary.items(), 
                                     key=lambda x: x[1]['mean_accuracy']):
        print(f"   - {class_name}: {metrics['mean_accuracy']:.4f} ± {metrics['std_accuracy']:.4f}")
    
    # Create aggregate confusion matrix
    class_names = [label_mapping[i] for i in range(len(label_mapping))]
    aggregate_cm = np.zeros((len(class_names), len(class_names)))
    for analysis in all_error_analyses:
        aggregate_cm += analysis['confusion_matrix']
    
    # Plot aggregate confusion matrix
    plt.figure(figsize=(12, 10))
    sns.heatmap(aggregate_cm, annot=True, fmt='.1f', cmap='Blues',
               xticklabels=class_names, yticklabels=class_names)
    plt.xlabel('Predicted')
    plt.ylabel('True')
    plt.title('Aggregate Confusion Matrix Across All Iterations')
    plt.tight_layout()
    plt.savefig(f"{Config.OUTPUT_DIR}/error_analysis/aggregate_confusion_matrix.png", 
               dpi=300, bbox_inches='tight')
    
    # Generate aggregate report
    report_path = f"{Config.OUTPUT_DIR}/error_analysis/aggregate_error_analysis.txt"
    with open(report_path, 'w') as f:
        f.write("AGGREGATE ERROR ANALYSIS ACROSS ALL ITERATIONS\n")
        f.write("=" * 50 + "\n\n")
        
        f.write("MOST COMMON MISCLASSIFICATIONS:\n")
        f.write("-" * 30 + "\n")
        for error_pair, count in aggregated_common_errors[:15]:
            f.write(f"{error_pair}: {count} total errors\n")
        
        f.write("\nCLASS-WISE PERFORMANCE SUMMARY:\n")
        f.write("-" * 30 + "\n")
        for class_name, metrics in sorted(class_metrics_summary.items(), 
                                         key=lambda x: x[1]['mean_accuracy']):
            f.write(f"\n{class_name}:\n")
            f.write(f"  Mean Accuracy: {metrics['mean_accuracy']:.4f}\n")
            f.write(f"  Std Deviation: {metrics['std_accuracy']:.4f}\n")
            f.write(f"  Range: [{metrics['min_accuracy']:.4f} - {metrics['max_accuracy']:.4f}]\n")
    
    print(f"\n✅ Aggregate error analysis saved to {report_path}")
    
    return {
        'aggregate_confusion_matrix': aggregate_cm,
        'common_errors': aggregated_common_errors,
        'class_metrics': class_metrics_summary
    }

def main():
    """Main pipeline execution with comprehensive statistical robustness analysis"""
    
    print("🔥 Consumer Complaint Classification - Statistical Robustness Pipeline")
    print("=" * 80)
    print(f"Model: {Config.MODEL_NAME}")
    print(f"Learning Rate: {Config.LEARNING_RATE}")
    print(f"Epochs: {Config.NUM_EPOCHS}")
    print(f"Iterations: {Config.NUM_ITERATIONS}")
    print(f"Space optimization: {'Enabled' if not Config.SAVE_MODELS else 'Disabled'}")
    print("=" * 80)
    
    # Set up environment
    set_seed(42)
    device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
    print(f"💻 Using device: {device}")
    
    # Create minimal output directory structure
    os.makedirs(Config.OUTPUT_DIR, exist_ok=True)

    # Create directory for error analysis
    os.makedirs(f"{Config.OUTPUT_DIR}/error_analysis", exist_ok=True)
    
    # Load and prepare data
    texts, labels, label_mapping, label_encoder = load_and_prepare_data()
    
    # Store results across iterations
    all_results = []
    all_error_analyses = []
    
    print(f"\n🔄 Starting {Config.NUM_ITERATIONS} iterations for statistical robustness...")
    print("-" * 80)
    
    # Run multiple iterations with different splits
    for iteration in range(Config.NUM_ITERATIONS):
        print(f"\n📋 ITERATION {iteration + 1}/{Config.NUM_ITERATIONS}")
        print("-" * 40)
        
        # Create new splits for this iteration
        train_data, val_data, test_data = create_stratified_splits(texts, labels, iteration)
        
        # Initialize fresh model for each iteration
        model, tokenizer = setup_model_and_tokenizer(len(label_mapping), model_type="distilbert", peft_type="lora")
        model.to(device)
        
        # Train and evaluate
        results = train_single_iteration(
            iteration, train_data, val_data, test_data, 
            model, tokenizer, label_mapping
        )
        
        all_results.append(results)
        all_error_analyses.append(results['error_analysis'])
        
        # Track and potentially save best model
        if Config.SAVE_ONLY_BEST_MODEL:
            is_best = track_best_model(all_results, iteration, model, tokenizer)
            if is_best:
                print(f"⭐ This is the new best model!")
        
        print(f"✅ Iteration {iteration + 1} completed!")
        
        # Clear CUDA cache and delete model to free memory
        del model, tokenizer
        if torch.cuda.is_available():
            torch.cuda.empty_cache()
    
    # =====================================
    # AGGREGATE RESULTS & ANALYSIS
    # =====================================
    
    print("\n" + "=" * 80)
    print("📊 FINAL STATISTICAL ROBUSTNESS ANALYSIS")
    print("=" * 80)
    
    # Create comprehensive results summary
    results_summary = create_results_summary(all_results)
    
    # Print aggregated statistics
    print(f"\n📈 AGGREGATED METRICS ACROSS {Config.NUM_ITERATIONS} ITERATIONS:")
    print("-" * 60)
    for metric in ['accuracy', 'f1', 'precision', 'recall']:
        stats = results_summary[metric]
        print(f"{metric.capitalize():12}: {stats['mean']:.4f} ± {stats['std']:.4f} "
              f"[{stats['min']:.4f} - {stats['max']:.4f}]")
    
    print(f"\n📊 INDIVIDUAL ITERATION RESULTS:")
    print("-" * 60)
    for i, results in enumerate(all_results):
        print(f"Iteration {i+1:2d}: Acc={results['accuracy']:.4f}, "
              f"F1={results['f1']:.4f}, Prec={results['precision']:.4f}, "
              f"Rec={results['recall']:.4f}")
    
    # Perform aggregate error analysis
    print("\n" + "=" * 80)
    print("🔍 COMPREHENSIVE ERROR ANALYSIS")
    print("=" * 80)
    
    aggregate_errors = aggregate_error_analysis(all_error_analyses, label_mapping)

    # Create visualization
    plot_results_distribution(results_summary)
    
    # Save only essential results (lightweight)
    results_df = pd.DataFrame([
        {
            'iteration': r['iteration'],
            'accuracy': r['accuracy'],
            'f1': r['f1'],
            'precision': r['precision'],
            'recall': r['recall'],
            'train_steps': r['train_steps']
        }
        for r in all_results
    ])
    
    results_df.to_csv(f'{Config.OUTPUT_DIR}/detailed_results.csv', index=False)
    
    # Save summary statistics
    summary_df = pd.DataFrame([
        {
            'metric': metric,
            'mean': stats['mean'],
            'std': stats['std'],
            'min': stats['min'],
            'max': stats['max']
        }
        for metric, stats in results_summary.items()
    ])
    
    summary_df.to_csv(f'{Config.OUTPUT_DIR}/summary_statistics.csv', index=False)
    
    print(f"\n✅ Pipeline completed successfully!")
    print(f"📁 Results saved in: {Config.OUTPUT_DIR}")
    print(f"📈 Check Weights & Biases project: {Config.WANDB_PROJECT}")
    print(f"📊 Visualizations saved as: {Config.OUTPUT_DIR}/results_distribution.png")
    print(f"🔍 Error analysis saved in: {Config.OUTPUT_DIR}/error_analysis/")
    
    if Config.SAVE_ONLY_BEST_MODEL:
        print(f"💾 Best model saved in: {Config.OUTPUT_DIR}/best_model_overall")
    
    # Final recommendations based on results
    acc_std = results_summary['accuracy']['std']
    if acc_std < 0.01:
        print("\n🎯 CONCLUSION: Model shows STRONG statistical robustness (low variance)")
    elif acc_std < 0.02:
        print("\n⚖️  CONCLUSION: Model shows MODERATE statistical robustness")
    else:
        print("\n⚠️  CONCLUSION: Model shows HIGH variance - consider more data or different approach")

if __name__ == "__main__":
    main()
# Out:
# wandb: WARNING If you're specifying your api key in code, ensure this code is not shared publicly.
# wandb: WARNING Consider setting the WANDB_API_KEY environment variable, or running `wandb login` from the command line.
# wandb: Appending key for api.wandb.ai to your netrc file: /teamspace/studios/this_studio/.netrc
# wandb: Currently logged in as: andretiagosilva77 (andretiagosilva77-faculdade-de-engenharia-da-universidad) to https://api.wandb.ai. Use `wandb login --relogin` to force relogin
# 🔥 Consumer Complaint Classification - Statistical Robustness Pipeline
# ================================================================================
# Model: distilbert-base-uncased
# Learning Rate: 2e-05
# Epochs: 10
# Iterations: 5
# Space optimization: Enabled
# ================================================================================
# 💻 Using device: cuda
# 📊 Loading and preparing dataset...
#    Original dataset size: 2023066
#    Original class distribution:
# product_5
# Credit Reporting              1205275
# Debt Collection                266842
# Loans                          228599
# Credit Card Services           163710
# Bank Accounts and Services     158640
# Name: count, dtype: int64
# ✅ Balanced dataset prepared: 12500 samples
# 📋 Classes (5): ['Bank Accounts and Services', 'Credit Card Services', 'Credit Reporting', 'Debt Collection', 'Loans']
# 📋 Samples per class: 2500
#
# 🔄 Starting 5 iterations for statistical robustness...
# --------------------------------------------------------------------------------
#
# 📋 ITERATION 1/5
# ----------------------------------------
# 🔄 Split 1: Train=8750, Val=1875, Test=1875
#    Train classes: {0: 1750, 1: 1750, 2: 1750, 3: 1750, 4: 1750}
#    Val classes: {0: 375, 1: 375, 2: 375, 3: 375, 4: 375}
#    Test classes: {0: 375, 1: 375, 2: 375, 3: 375, 4: 375}
# 🤖 Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# wandb: WARNING Using a boolean value for 'reinit' is deprecated. Use 'return_previous' or 'finish_previous' instead.
# 🚀 Starting training for iteration 1...
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/teamspace/studios/this_studio/consumer-complaint-transformer-classifier/wandb/run-20250524_222508-wfiwfx0r</code>
# Syncing run <strong><a href='https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora/runs/wfiwfx0r' target="_blank">iteration_1</a></strong> to <a href='https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora' target="_blank">https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora</a>
#  View run at <a href='https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora/runs/wfiwfx0r' target="_blank">https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora/runs/wfiwfx0r</a>
# No label_names provided for model class `PeftModelForSequenceClassification`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
#    Training with 8750 samples...
#     <div>
#
#       <progress value='2400' max='5470' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2400/5470 10:50 < 13:53, 3.68 it/s, Epoch 4/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Per Class Mean</th>
#       <th>Precision Per Class Mean</th>
#       <th>Recall Per Class Mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>1.609300</td>
#       <td>1.609218</td>
#       <td>0.184000</td>
#       <td>0.082359</td>
#       <td>0.257118</td>
#       <td>0.184000</td>
#       <td>0.082359</td>
#       <td>0.257118</td>
#       <td>0.184000</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.604900</td>
#       <td>1.597835</td>
#       <td>0.216000</td>
#       <td>0.143117</td>
#       <td>0.577161</td>
#       <td>0.216000</td>
#       <td>0.143117</td>
#       <td>0.577161</td>
#       <td>0.216000</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.583800</td>
#       <td>1.577127</td>
#       <td>0.373867</td>
#       <td>0.358992</td>
#       <td>0.508906</td>
#       <td>0.373867</td>
#       <td>0.358992</td>
#       <td>0.508906</td>
#       <td>0.373867</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1.545800</td>
#       <td>1.523672</td>
#       <td>0.434667</td>
#       <td>0.357700</td>
#       <td>0.579932</td>
#       <td>0.434667</td>
#       <td>0.357700</td>
#       <td>0.579932</td>
#       <td>0.434667</td>
#     </tr>
#     <tr>
#       <td>500</td>
#       <td>1.416200</td>
#       <td>1.342476</td>
#       <td>0.581333</td>
#       <td>0.561947</td>
#       <td>0.585879</td>
#       <td>0.581333</td>
#       <td>0.561947</td>
#       <td>0.585879</td>
#       <td>0.581333</td>
#     </tr>
#     <tr>
#       <td>600</td>
#       <td>1.156500</td>
#       <td>1.068460</td>
#       <td>0.645867</td>
#       <td>0.637709</td>
#       <td>0.676510</td>
#       <td>0.645867</td>
#       <td>0.637709</td>
#       <td>0.676510</td>
#       <td>0.645867</td>
#     </tr>
#     <tr>
#       <td>700</td>
#       <td>0
td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.702400</td>
#       <td>0.663895</td>
#       <td>0.766933</td>
#       <td>0.765637</td>
#       <td>0.767298</td>
#       <td>0.766933</td>
#       <td>0.765637</td>
#       <td>0.767298</td>
#       <td>0.766933</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.636700</td>
#       <td>0.656253</td>
#       <td>0.765333</td>
#       <td>0.764534</td>
#       <td>0.765833</td>
#       <td>0.765333</td>
#       <td>0.764534</td>
#       <td>0.765833</td>
#       <td>0.765333</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.665200</td>
#       <td>0.656972</td>
#       <td>0.765867</td>
#       <td>0.764788</td>
#       <td>0.766692</td>
#       <td>0.765867</td>
#       <td>0.764788</td>
#       <td>0.766692</td>
#       <td>0.765867</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.618600</td>
#       <td>0.650718</td>
#       <td>0.766933</td>
#       <td>0.765869</td>
#       <td>0.767611</td>
#       <td>0.766933</td>
#       <td>0.765869</td>
#       <td>0.767611</td>
#       <td>0.766933</td>
#     </tr>
#   </tbody>
# </table><p>
# early stopping required metric_for_best_model, but did not find eval_accuracy so early stopping is disabled
# 🔍 ERROR ANALYSIS FOR ITERATION 1
# ----------------------------------------
#    Total test samples: 1875
#    Correctly classified: 1384 (73.81%)
#    Misclassified: 491 (26.19%)
#
#    Most common misclassifications:
#    - Debt Collection → Credit Reporting: 68 samples (13.8% of errors)
#    - Bank Accounts and Services → Credit Card Services: 48 samples (9.8% of errors)
#    - Credit Card Services → Bank Accounts and Services: 43 samples (8.8% of errors)
#    - Debt Collection → Loans: 37 samples (7.5% of errors)
#    - Credit Reporting → Debt Collection: 37 samples (7.5% of errors)
#    Error analysis report saved to ./outputs/error_analysis/report_iter_1.txt
# 📈 Results: Acc=0.7381, F1=0.7368
# 🗑️  Cleaned up temporary files for iteration 1
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>error_rate</td><td>▁</td></tr><tr><td>eval/accuracy</td><td>▁▁▃▄▆▇▇▇████████████████</td></tr><tr><td>eval/f1</td><td>▁▂▄▄▆▇▇█████████████████</td></tr><tr><td>eval/f1_per_class_mean</td><td>▁▂▄▄▆▇▇█████████████████</td></tr><tr><td>eval/loss</td><td>███▇▆▄▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/precision</td><td>▁▅▄▅▆▇▇▇▇███████████████</td></tr><tr><td>eval/precision_per_class_mean</td><td>▁▅▄▅▆▇▇▇▇███████████████</td></tr><tr><td>eval/recall</td><td>▁▁▃▄▆▇▇▇████████████████</td></tr><tr><td>eval/recall_per_class_mean</td><td>▁▁▃▄▆▇▇▇████████████████</td></tr><tr><td>eval/runtime</td><td>▃▂▁▁▆▄▄▂▃▇▆▆▅▆▆▇▇▇▇█▇▇▇█</td></tr><tr><td>eval/samples_per_second</td><td>▆▇██▃▅▅▇▆▂▃▃▄▃▃▂▂▂▂▁▂▂▂▁</td></tr><tr><td>eval/steps_per_second</td><td>▆▇██▃▅▅▇▆▂▃▃▄▃▃▂▂▂▂▁▂▂▂▁</td></tr><tr><td>iteration</td><td>▁</td></tr><tr><td>test/accuracy</td><td>▁▁</td></tr><tr><td>test/f1</td><td>▁▁</td></tr><tr><td>test/f1_per_class_mean</td><td>▁▁</td></tr><tr><td>test/loss</td><td>▁▁</td></tr><tr><td>test/precision</td><td>▁▁</td></tr><tr><td>test/precision_per_class_mean</td><td>▁▁</td></tr><tr><td>test/recall</td><td>▁▁</td></tr><tr><td>test/recall_per_class_mean</td><td>▁▁</td></tr><tr><td>test/runtime</td><td>▁█</td></tr><tr><td>test/samples_per_second</td><td>█▁</td></tr><tr><td>test/steps_per_second</td><td>█▁</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>top_error_count</td><td>▁</td></tr><tr><td>total_train_steps</td><td>▁</td></tr><tr><td>train/epoch</td><td>▁▁▁▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▄▄▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇█████</td></tr><tr><td>train/global_step</td><td>▁▁▁▁▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▄▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇█████</td></tr><tr><td>train/grad_norm</td><td>▂▁▃▁▁▂▁▁▂▃▆▄▄▄▅▃▅▄▄▆▂▄▅▃▄▇▅▇▄▇▅▃▄▆▅█▃▄▆▆</td></tr><tr><td>train/learning_rate</td><td>▁▂▂▃▄▅▆▇▇██████▇▇▇▇▇▇▇▇▇▇▇▆▆▆▆▆▆▆▆▆▆▆▆▅▅</td></tr><tr><td>train/loss</td><td>███████▇▇▇▄▃▃▃▃▂▂▂▂▂▂▂▂▂▁▁▂▁▁▁▁▁▁▁▁▂▁▁▁▁</td></tr><tr><td>train_runtime</td><td>▁</td></tr><tr><td>train_samples_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>error_rate</td><td>0.26187</td></tr><tr><td>eval/accuracy</td><td>0.76693</td></tr><tr><td>eval/f1</td><td>0.76587</td></tr><tr><td>eval/f1_per_class_mean</td><td>0.76587</td></tr><tr><td>eval/loss</td><td>0.65072</td></tr><tr><td>eval/precision</td><td>0.76761</td></tr><tr><td>eval/precision_per_class_mean</td><td>0.76761</td></tr><tr><td>eval/recall</td><td>0.76693</td></tr><tr><td>eval/recall_per_class_mean</td><td>0.76693</td></tr><tr><td>eval/runtime</td><td>9.1539</td></tr><tr><td>eval/samples_per_second</td><td>204.832</td></tr><tr><td>eval/steps_per_second</td><td>12.891</td></tr><tr><td>iteration</td><td>1</td></tr><tr><td>test/accuracy</td><td>0.73813</td></tr><tr><td>test/f1</td><td>0.73681</td></tr><tr><td>test/f1_per_class_mean</td><td>0.73681</td></tr><tr><td>test/loss</td><td>0.73823</td></tr><tr><td>test/precision</td><td>0.73733</td></tr><tr><td>test/precision_per_class_mean</td><td>0.73733</td></tr><tr><td>test/recall</td><td>0.73813</td></tr><tr><td>test/recall_per_class_mean</td><td>0.73813</td></tr><tr><td>test/runtime</td><td>9.2268</td></tr><tr><td>test/samples_per_second</td><td>203.211</td></tr><tr><td>test/steps_per_second</td><td>12.789</td></tr><tr><td>test_accuracy</td><td>0.73813</td></tr><tr><td>test_f1</td><td>0.73681</td></tr><tr><td>test_precision ...
#  View run <strong style="color:#cdcd00">iteration_1</strong> at: <a href='https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora/runs/wfiwfx0r' target="_blank">https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora/runs/wfiwfx0r</a><br> View project at: <a href='https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora' target="_blank">https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250524_222508-wfiwfx0r/logs</code>
# 💾 New best model saved! Accuracy: 0.7381
# ⭐ This is the new best model!
# ✅ Iteration 1 completed!
#
# 📋 ITERATION 2/5
# ----------------------------------------
# 🔄 Split 2: Train=8750, Val=1875, Test=1875
#    Train classes: {0: 1750, 1: 1750, 2: 1750, 3: 1750, 4: 1750}
#    Val classes: {0: 375, 1: 375, 2: 375, 3: 375, 4: 375}
#    Test classes: {0: 375, 1: 375, 2: 375, 3: 375, 4: 375}
# 🤖 Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 🚀 Starting training for iteration 2...
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/teamspace/studios/this_studio/consumer-complaint-transformer-classifier/wandb/run-20250524_223621-do5g39q4</code>
# Syncing run <strong><a href='https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora/runs/do5g39q4' target="_blank">iteration_2</a></strong> to <a href='https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora' target="_blank">https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora</a>
#  View run at <a href='https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora/runs/do5g39q4' target="_blank">https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora/runs/do5g39q4</a>
# No label_names provided for model class `PeftModelForSequenceClassification`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
td>
#     </tr>
#     <tr>
#       <td>2700</td>
#       <td>0.635500</td>
#       <td>0.625171</td>
#       <td>0.781333</td>
#       <td>0.780605</td>
#       <td>0.781126</td>
#       <td>0.781333</td>
#       <td>0.780605</td>
#       <td>0.781126</td>
#       <td>0.781333</td>
#     </tr>
#   </tbody>
# </table><p>
# early stopping required metric_for_best_model, but did not find eval_accuracy so early stopping is disabled
# 🔍 ERROR ANALYSIS FOR ITERATION 2
# ----------------------------------------
#    Total test samples: 1875
#    Correctly classified: 1454 (77.55%)
#    Misclassified: 421 (22.45%)
#
#    Most common misclassifications:
#    - Debt Collection → Credit Reporting: 61 samples (14.5% of errors)
#    - Bank Accounts and Services → Credit Card Services: 56 samples (13.3% of errors)
#    - Credit Card Services → Bank Accounts and Services: 44 samples (10.5% of errors)
#    - Debt Collection → Loans: 28 samples (6.7% of errors)
#    - Credit Reporting → Debt Collection: 27 samples (6.4% of errors)
#    Error analysis report saved to ./outputs/error_analysis/report_iter_2.txt
# 📈 Results: Acc=0.7755, F1=0.7749
# 🗑️  Cleaned up temporary files for iteration 2
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>error_rate</td><td>▁</td></tr><tr><td>eval/accuracy</td><td>▁▂▃▃▄▆▇▇▇▇█████████████████</td></tr><tr><td>eval/f1</td><td>▁▂▃▃▄▆▇▇▇▇█████████████████</td></tr><tr><td>eval/f1_per_class_mean</td><td>▁▂▃▃▄▆▇▇▇▇█████████████████</td></tr><tr><td>eval/loss</td><td>███▇▆▅▃▃▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/precision</td><td>▁▄▄▄▅▆▇▇▇▇█████████████████</td></tr><tr><td>eval/precision_per_class_mean</td><td>▁▄▄▄▅▆▇▇▇▇█████████████████</td></tr><tr><td>eval/recall</td><td>▁▂▃▃▄▆▇▇▇▇█████████████████</td></tr><tr><td>eval/recall_per_class_mean</td><td>▁▂▃▃▄▆▇▇▇▇█████████████████</td></tr><tr><td>eval/runtime</td><td>▇▅▆█▆▃▆▅▄▂▄▅▃▄▅▃▂▄▃▃▃▆▂▂▄▁▃</td></tr><tr><td>eval/samples_per_second</td><td>▂▄▃▁▃▆▃▄▅▇▅▄▆▅▄▆▇▅▆▆▆▃▇▇▅█▆</td></tr><tr><td>eval/steps_per_second</td><td>▂▄▃▁▃▆▃▄▅▇▅▄▆▅▄▆▇▅▆▆▆▃▇▇▅█▆</td></tr><tr><td>iteration</td><td>▁</td></tr><tr><td>test/accuracy</td><td>▁▁</td></tr><tr><td>test/f1</td><td>▁▁</td></tr><tr><td>test/f1_per_class_mean</td><td>▁▁</td></tr><tr><td>test/loss</td><td>▁▁</td></tr><tr><td>test/precision</td><td>▁▁</td></tr><tr><td>test/precision_per_class_mean</td><td>▁▁</td></tr><tr><td>test/recall</td><td>▁▁</td></tr><tr><td>test/recall_per_class_mean</td><td>▁▁</td></tr><tr><td>test/runtime</td><td>▁█</td></tr><tr><td>test/samples_per_second</td><td>█▁</td></tr><tr><td>test/steps_per_second</td><td>█▁</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>top_error_count</td><td>▁</td></tr><tr><td>total_train_steps</td><td>▁</td></tr><tr><td>train/epoch</td><td>▁▁▂▂▂▂▂▂▂▂▃▃▃▃▃▃▃▄▄▄▄▄▄▅▅▆▆▆▆▇▇▇▇▇▇█████</td></tr><tr><td>train/global_step</td><td>▁▁▁▁▂▂▂▂▃▃▃▄▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▇▇▇▇▇▇▇██████</td></tr><tr><td>train/grad_norm</td><td>▁▂▁▁▂▂▂▂▁▄▅▄▄▃▃▅▄▃▄▄▅▃▄▅▄▆▄█▄▇▅▇▆▆▃▇▅▄▅▅</td></tr><tr><td>train/learning_rate</td><td>▁▂▂▃▄▅▇▇███████▇▇▇▇▇▇▇▇▇▆▆▆▆▆▆▆▆▆▆▆▅▅▅▅▅</td></tr><tr><td>train/loss</td><td>███████▇▇▆▅▄▄▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▁▂▁▂▂▂▂▁▂▁▂▂</td></tr><tr><td>train_runtime</td><td>▁</td></tr><tr><td>train_samples_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>error_rate</td><td>0.22453</td></tr><tr><td>eval/accuracy</td><td>0.78133</td></tr><tr><td>eval/f1</td><td>0.7806</td></tr><tr><td>eval/f1_per_class_mean</td><td>0.7806</td></tr><tr><td>eval/loss</td><td>0.62517</td></tr><tr><td>eval/precision</td><td>0.78113</td></tr><tr><td>eval/precision_per_class_mean</td><td>0.78113</td></tr><tr><td>eval/recall</td><td>0.78133</td></tr><tr><td>eval/recall_per_class_mean</td><td>0.78133</td></tr><tr><td>eval/runtime</td><td>9.1853</td></tr><tr><td>eval/samples_per_second</td><td>204.13</td></tr><tr><td>eval/steps_per_second</td><td>12.847</td></tr><tr><td>iteration</td><td>2</td></tr><tr><td>test/accuracy</td><td>0.77547</td></tr><tr><td>test/f1</td><td>0.77487</td></tr><tr><td>test/f1_per_class_mean</td><td>0.77487</td></tr><tr><td>test/loss</td><td>0.64547</td></tr><tr><td>test/precision</td><td>0.77719</td></tr><tr><td>test/precision_per_class_mean</td><td>0.77719</td></tr><tr><td>test/recall</td><td>0.77547</td></tr><tr><td>test/recall_per_class_mean</td><td>0.77547</td></tr><tr><td>test/runtime</td><td>9.3582</td></tr><tr><td>test/samples_per_second</td><td>200.359</td></tr><tr><td>test/steps_per_second</td><td>12.609</td></tr><tr><td>test_accuracy</td><td>0.77547</td></tr><tr><td>test_f1</td><td>0.77487</ ...
#  View run <strong style="color:#cdcd00">iteration_2</strong> at: <a href='https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora/runs/do5g39q4' target="_blank">https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora/runs/do5g39q4</a><br> View project at: <a href='https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora' target="_blank">https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250524_223621-do5g39q4/logs</code>
# 💾 New best model saved! Accuracy: 0.7755
# ⭐ This is the new best model!
# ✅ Iteration 2 completed!
#
# 📋 ITERATION 3/5
# ----------------------------------------
# 🔄 Split 3: Train=8750, Val=1875, Test=1875
#    Train classes: {0: 1750, 1: 1750, 2: 1750, 3: 1750, 4: 1750}
#    Val classes: {0: 375, 1: 375, 2: 375, 3: 375, 4: 375}
#    Test classes: {0: 375, 1: 375, 2: 375, 3: 375, 4: 375}
# 🤖 Loading model: distilbert-base-uncased
# Some weights of DistilBertForSequenceClassification were not initialized from the model checkpoint at distilbert-base-uncased and are newly initialized: ['classifier.bias', 'classifier.weight', 'pre_classifier.bias', 'pre_classifier.weight']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.
# 🚀 Starting training for iteration 3...
# Tracking run with wandb version 0.19.11
# Run data is saved locally in <code>/teamspace/studios/this_studio/consumer-complaint-transformer-classifier/wandb/run-20250524_224905-61ioviov</code>
# Syncing run <strong><a href='https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora/runs/61ioviov' target="_blank">iteration_3</a></strong> to <a href='https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br>
#  View project at <a href='https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora' target="_blank">https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora</a>
#  View run at <a href='https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora/runs/61ioviov' target="_blank">https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora/runs/61ioviov</a>
# No label_names provided for model class `PeftModelForSequenceClassification`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
#    Training with 8750 samples...
#     <div>
#
#       <progress value='4200' max='5470' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [4200/5470 19:13 < 05:49, 3.64 it/s, Epoch 7/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Per Class Mean</th>
#       <th>Precision Per Class Mean</th>
#       <th>Recall Per Class Mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>1.611300</td>
#       <td>1.612144</td>
#       <td>0.209600</td>
#       <td>0.095521</td>
#       <td>0.119983</td>
#       <td>0.209600</td>
#       <td>0.095521</td>
#       <td>0.119983</td>
#       <td>0.209600</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.605000</td>
#       <td>1.596038</td>
#       <td>0.320000</td>
#       <td>0.239978</td>
#       <td>0.242804</td>
#       <td>0.320000</td>
#       <td>0.239978</td>
#       <td>0.242804</td>
#       <td>0.320000</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1
#    Total test samples: 1875
#    Correctly classified: 1446 (77.12%)
#    Misclassified: 429 (22.88%)
#
#    Most common misclassifications:
#    - Debt Collection → Credit Reporting: 85 samples (19.8% of errors)
#    - Bank Accounts and Services → Credit Card Services: 46 samples (10.7% of errors)
#    - Credit Card Services → Bank Accounts and Services: 46 samples (10.7% of errors)
#    - Credit Reporting → Debt Collection: 26 samples (6.1% of errors)
#    - Credit Card Services → Credit Reporting: 25 samples (5.8% of errors)
#    Error analysis report saved to ./outputs/error_analysis/report_iter_3.txt
# 📈 Results: Acc=0.7712, F1=0.7703
# 🗑️  Cleaned up temporary files for iteration 3
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>error_rate</td><td>▁</td></tr><tr><td>eval/accuracy</td><td>▁▂▃▃▄▆▇▇▇▇▇▇████████████████████████████</td></tr><tr><td>eval/f1</td><td>▁▂▃▂▄▆▇▇▇▇██████████████████████████████</td></tr><tr><td>eval/f1_per_class_mean</td><td>▁▂▃▂▄▆▇▇▇▇██████████████████████████████</td></tr><tr><td>eval/loss</td><td>███▇▆▅▃▃▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/precision</td><td>▁▂▃▅▆▆▇▇▇▇▇█████████████████████████████</td></tr><tr><td>eval/precision_per_class_mean</td><td>▁▂▃▅▆▆▇▇▇▇▇█████████████████████████████</td></tr><tr><td>eval/recall</td><td>▁▂▃▃▄▆▇▇▇▇▇▇████████████████████████████</td></tr><tr><td>eval/recall_per_class_mean</td><td>▁▂▃▃▄▆▇▇▇▇▇▇████████████████████████████</td></tr><tr><td>eval/runtime</td><td>▅▅▅▅▄▇▄▇▅▅▅▆▅▅█▄▄▅▁▄▂▃▂▄▄▄▄▆▄▇▅▆▃▅▂▆▃▄▃█</td></tr><tr><td>eval/samples_per_second</td><td>▄▄▄▄▅▂▅▂▄▄▄▃▄▄▁▅▅▄█▅▇▆▇▅▅▅▅▃▅▂▄▃▆▄▇▃▆▅▆▁</td></tr><tr><td>eval/steps_per_second</td><td>▄▄▄▄▅▂▅▂▄▄▄▃▄▄▁▅▅▄█▅▇▆▇▅▅▅▅▃▅▂▄▃▆▄▇▃▆▅▆▁</td></tr><tr><td>iteration</td><td>▁</td></tr><tr><td>test/accuracy</td><td>▁▁</td></tr><tr><td>test/f1</td><td>▁▁</td></tr><tr><td>test/f1_per_class_mean</td><td>▁▁</td></tr><tr><td>test/loss</td><td>▁▁</td></tr><tr><td>test/precision</td><td>▁▁</td></tr><tr><td>test/precision_per_class_mean</td><td>▁▁</td></tr><tr><td>test/recall</td><td>▁▁</td></tr><tr><td>test/recall_per_class_mean</td><td>▁▁</td></tr><tr><td>test/runtime</td><td>▁█</td></tr><tr><td>test/samples_per_second</td><td>█▁</td></tr><tr><td>test/steps_per_second</td><td>█▁</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>top_error_count</td><td>▁</td></tr><tr><td>total_train_steps</td><td>▁</td></tr><tr><td>train/epoch</td><td>▁▁▁▂▂▂▂▂▃▃▃▃▃▄▄▄▄▄▄▄▄▄▄▄▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇█</td></tr><tr><td>train/global_step</td><td>▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▄▄▄▅▅▅▆▆▆▆▆▆▇▇▇█████</td></tr><tr><td>train/grad_norm</td><td>▁▂▂▃▃▂▃▆█▄▆▇▅█▄▆▄▇▅▆▆▄▄▄▄▅▆█▅▅▄▇▆▆▄▆█▄▆▇</td></tr><tr><td>train/learning_rate</td><td>▁▂▃▅▅█████▇▇▇▇▇▆▆▆▆▆▆▅▅▅▅▅▅▅▅▅▄▄▄▄▄▄▄▃▃▃</td></tr><tr><td>train/loss</td><td>█████▇▅▃▃▃▂▂▂▂▂▂▁▂▂▂▂▁▂▁▂▂▁▂▂▁▁▂▁▁▂▁▁▂▁▁</td></tr><tr><td>train_runtime</td><td>▁</td></tr><tr><td>train_samples_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>error_rate</td><td>0.2288</td></tr><tr><td>eval/accuracy</td><td>0.79893</td></tr><tr><td>eval/f1</td><td>0.7989</td></tr><tr><td>eval/f1_per_class_mean</td><td>0.7989</td></tr><tr><td>eval/loss</td><td>0.59907</td></tr><tr><td>eval/precision</td><td>0.80018</td></tr><tr><td>eval/precision_per_class_mean</td><td>0.80018</td></tr><tr><td>eval/recall</td><td>0.79893</td></tr><tr><td>eval/recall_per_class_mean</td><td>0.79893</td></tr><tr><td>eval/runtime</td><td>9.2761</td></tr><tr><td>eval/samples_per_second</td><td>202.132</td></tr><tr><td>eval/steps_per_second</td><td>12.721</td></tr><tr><td>iteration</td><td>3</td></tr><tr><td>test/accuracy</td><td>0.7712</td></tr><tr><td>test/f1</td><td>0.77028</td></tr><tr><td>test/f1_per_class_mean</td><td>0.77028</td></tr><tr><td>test/loss</td><td>0.64565</td></tr><tr><td>test/precision</td><td>0.77433</td></tr><tr><td>test/precision_per_class_mean</td><td>0.77433</td></tr><tr><td>test/recall</td><td>0.7712</td></tr><tr><td>test/recall_per_class_mean</td><td>0.7712</td></tr><tr><td>test/runtime</td><td>9.53</td></tr><tr><td>test/samples_per_second</td><td>196.746</td>< ...
#  View run <strong style="color:#cdcd00">iteration_3</strong> at: <a href='https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora/runs/61ioviov' target="_blank">https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora/runs/61ioviov</a><br> View project at: <a href='https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora' target="_blank">https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250524_224905-61ioviov/logs</code>
# ✅ Iteration 3 completed!
#
# 📋 ITERATION 4/5
# ----------------------------------------
# 🔄 Split 4: Train=8750, Val=1875, Test=1875
#    Train classes: {0: 1750, 1: 1750, 2: 1750, 3: 1750, 4: 1750}
#    Val classes: {0: 375, 1: 375, 2: 375, 3: 375, 4: 375}
#    Test classes: {0: 375, 1: 375, 2: 375, 3: 375, 4: 375}
# 🤖 Loading model: distilbert-base-uncased
# ...
#  View project at <a href='https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora' target="_blank">https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora</a>
#  View run at <a href='https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora/runs/ghoi2nxe' target="_blank">https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora/runs/ghoi2nxe</a>
# No label_names provided for model class `PeftModelForSequenceClassification`. Since `PeftModel` hides base models input arguments, if label_names is not given, label_names can't be set automatically within `Trainer`. Note that empty label_names list will be used instead.
#    Training with 8750 samples...
#     <div>
#
#       <progress value='2400' max='5470' style='width:300px; height:20px; vertical-align: middle;'></progress>
#       [2400/5470 11:01 < 14:06, 3.63 it/s, Epoch 4/10]
#     </div>
#     <table border="1" class="dataframe">
#   <thead>
#  <tr style="text-align: left;">
#       <th>Step</th>
#       <th>Training Loss</th>
#       <th>Validation Loss</th>
#       <th>Accuracy</th>
#       <th>F1</th>
#       <th>Precision</th>
#       <th>Recall</th>
#       <th>F1 Per Class Mean</th>
#       <th>Precision Per Class Mean</th>
#       <th>Recall Per Class Mean</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>100</td>
#       <td>1.609800</td>
#       <td>1.606777</td>
#       <td>0.214400</td>
#       <td>0.121617</td>
#       <td>0.313107</td>
#       <td>0.214400</td>
#       <td>0.121617</td>
#       <td>0.313107</td>
#       <td>0.214400</td>
#     </tr>
#     <tr>
#       <td>200</td>
#       <td>1.598700</td>
#       <td>1.592059</td>
#       <td>0.312533</td>
#       <td>0.183142</td>
#       <td>0.313321</td>
#       <td>0.312533</td>
#       <td>0.183142</td>
#       <td>0.313321</td>
#       <td>0.312533</td>
#     </tr>
#     <tr>
#       <td>300</td>
#       <td>1.580000</td>
#       <td>1.565779</td>
#       <td>0.446933</td>
#       <td>0.347890</td>
#       <td>0.424083</td>
#       <td>0.446933</td>
#       <td>0.347890</td>
#       <td>0.424083</td>
#       <td>0.446933</td>
#     </tr>
#     <tr>
#       <td>400</td>
#       <td>1
td>
#     </tr>
#     <tr>
#       <td>1800</td>
#       <td>0.689300</td>
#       <td>0.644122</td>
#       <td>0.771733</td>
#       <td>0.770818</td>
#       <td>0.773255</td>
#       <td>0.771733</td>
#       <td>0.770818</td>
#       <td>0.773255</td>
#       <td>0.771733</td>
#     </tr>
#     <tr>
#       <td>1900</td>
#       <td>0.677400</td>
#       <td>0.644089</td>
#       <td>0.763200</td>
#       <td>0.762290</td>
#       <td>0.768567</td>
#       <td>0.763200</td>
#       <td>0.762290</td>
#       <td>0.768567</td>
#       <td>0.763200</td>
#     </tr>
#     <tr>
#       <td>2000</td>
#       <td>0.697800</td>
#       <td>0.637496</td>
#       <td>0.777067</td>
#       <td>0.777242</td>
#       <td>0.779556</td>
#       <td>0.777067</td>
#       <td>0.777242</td>
#       <td>0.779556</td>
#       <td>0.777067</td>
#     </tr>
#     <tr>
#       <td>2100</td>
#       <td>0.654600</td>
#       <td>0.626411</td>
#       <td>0.783467</td>
#       <td>0.783114</td>
#       <td>0.784347</td>
#       <td>0.783467</td>
#       <td>0.783114</td>
#       <td>0.784347</td>
#       <td>0.783467</td>
#     </tr>
#     <tr>
#       <td>2200</td>
#       <td>0.642000</td>
#       <td>0.626685</td>
#       <td>0.775467</td>
#       <td>0.775176</td>
#       <td>0.779866</td>
#       <td>0.775467</td>
#       <td>0.775176</td>
#       <td>0.779866</td>
#       <td>0.775467</td>
#     </tr>
#     <tr>
#       <td>2300</td>
#       <td>0.645800</td>
#       <td>0.620430</td>
#       <td>0.784000</td>
#       <td>0.783619</td>
#       <td>0.785448</td>
#       <td>0.784000</td>
#       <td>0.783619</td>
#       <td>0.785448</td>
#       <td>0.784000</td>
#     </tr>
#     <tr>
#       <td>2400</td>
#       <td>0.578100</td>
#       <td>0.620645</td>
#       <td>0.776533</td>
#       <td>0.776164</td>
#       <td>0.780651</td>
#       <td>0.776533</td>
#       <td>0.776164</td>
#       <td>0.780651</td>
#       <td>0.776533</td>
#     </tr>
#   </tbody>
# </table><p>
# early stopping required metric_for_best_model, but did not find eval_accuracy so early stopping is disabled
# 🔍 ERROR ANALYSIS FOR ITERATION 5
# ----------------------------------------
#    Total test samples: 1875
#    Correctly classified: 1460 (77.87%)
#    Misclassified: 415 (22.13%)
#
#    Most common misclassifications:
#    - Debt Collection → Credit Reporting: 72 samples (17.3% of errors)
#    - Bank Accounts and Services → Credit Card Services: 41 samples (9.9% of errors)
#    - Credit Reporting → Debt Collection: 39 samples (9.4% of errors)
#    - Credit Card Services → Bank Accounts and Services: 39 samples (9.4% of errors)
#    - Credit Card Services → Credit Reporting: 35 samples (8.4% of errors)
#    Error analysis report saved to ./outputs/error_analysis/report_iter_5.txt
# 📈 Results: Acc=0.7787, F1=0.7785
# 🗑️  Cleaned up temporary files for iteration 5
# <br>    <style><br>        .wandb-row {<br>            display: flex;<br>            flex-direction: row;<br>            flex-wrap: wrap;<br>            justify-content: flex-start;<br>            width: 100%;<br>        }<br>        .wandb-col {<br>            display: flex;<br>            flex-direction: column;<br>            flex-basis: 100%;<br>            flex: 1;<br>            padding: 10px;<br>        }<br>    </style><br><div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>error_rate</td><td>▁</td></tr><tr><td>eval/accuracy</td><td>▁▂▄▄▆▆▇▇▇▇██████████████</td></tr><tr><td>eval/f1</td><td>▁▂▃▄▆▆▇▇▇▇██████████████</td></tr><tr><td>eval/f1_per_class_mean</td><td>▁▂▃▄▆▆▇▇▇▇██████████████</td></tr><tr><td>eval/loss</td><td>███▇▆▄▃▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>eval/precision</td><td>▁▁▃▄▆▆▇▇▇▇▇▇████████████</td></tr><tr><td>eval/precision_per_class_mean</td><td>▁▁▃▄▆▆▇▇▇▇▇▇████████████</td></tr><tr><td>eval/recall</td><td>▁▂▄▄▆▆▇▇▇▇██████████████</td></tr><tr><td>eval/recall_per_class_mean</td><td>▁▂▄▄▆▆▇▇▇▇██████████████</td></tr><tr><td>eval/runtime</td><td>▆▇▃▃▆▁▅▅▃▂▄▅▆▆██▆▂▄▅▅▄▅▄</td></tr><tr><td>eval/samples_per_second</td><td>▃▂▆▆▃█▄▄▆▇▅▄▃▃▁▁▃▇▅▄▄▅▄▅</td></tr><tr><td>eval/steps_per_second</td><td>▃▂▆▆▃█▄▄▆▇▅▄▃▃▁▁▃▇▅▄▄▅▄▅</td></tr><tr><td>iteration</td><td>▁</td></tr><tr><td>test/accuracy</td><td>▁▁</td></tr><tr><td>test/f1</td><td>▁▁</td></tr><tr><td>test/f1_per_class_mean</td><td>▁▁</td></tr><tr><td>test/loss</td><td>▁▁</td></tr><tr><td>test/precision</td><td>▁▁</td></tr><tr><td>test/precision_per_class_mean</td><td>▁▁</td></tr><tr><td>test/recall</td><td>▁▁</td></tr><tr><td>test/recall_per_class_mean</td><td>▁▁</td></tr><tr><td>test/runtime</td><td>▁█</td></tr><tr><td>test/samples_per_second</td><td>█▁</td></tr><tr><td>test/steps_per_second</td><td>█▁</td></tr><tr><td>test_accuracy</td><td>▁</td></tr><tr><td>test_f1</td><td>▁</td></tr><tr><td>test_precision</td><td>▁</td></tr><tr><td>test_recall</td><td>▁</td></tr><tr><td>top_error_count</td><td>▁</td></tr><tr><td>total_train_steps</td><td>▁</td></tr><tr><td>train/epoch</td><td>▁▁▁▁▁▂▂▂▂▂▂▃▃▃▃▄▄▄▄▄▄▄▄▅▅▅▅▅▅▆▆▇▇▇▇▇▇███</td></tr><tr><td>train/global_step</td><td>▁▁▁▂▂▂▂▃▃▃▃▃▃▄▄▄▄▄▅▅▅▅▅▆▆▆▆▆▆▇▇▇▇▇██████</td></tr><tr><td>train/grad_norm</td><td>▂▂▁▂▂▁▂▂▂▃▃▃▄▃▄▄▅▅▂▅▅▅▃▅▅▃▃▂▆▃▄▄▃█▃█▂▆▅▅</td></tr><tr><td>train/learning_rate</td><td>▁▂▂▃▄▆▇▇███████▇▇▇▇▇▇▇▇▇▇▇▆▆▆▆▆▆▆▆▆▆▆▆▅▅</td></tr><tr><td>train/loss</td><td>███████▇▇▆▄▃▃▃▃▂▂▂▂▂▂▂▂▂▂▂▂▂▁▂▂▂▁▂▂▂▁▁▁▁</td></tr><tr><td>train_runtime</td><td>▁</td></tr><tr><td>train_samples_per_second</td><td>▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>error_rate</td><td>0.22133</td></tr><tr><td>eval/accuracy</td><td>0.77653</td></tr><tr><td>eval/f1</td><td>0.77616</td></tr><tr><td>eval/f1_per_class_mean</td><td>0.77616</td></tr><tr><td>eval/loss</td><td>0.62065</td></tr><tr><td>eval/precision</td><td>0.78065</td></tr><tr><td>eval/precision_per_class_mean</td><td>0.78065</td></tr><tr><td>eval/recall</td><td>0.77653</td></tr><tr><td>eval/recall_per_class_mean</td><td>0.77653</td></tr><tr><td>eval/runtime</td><td>9.2047</td></tr><tr><td>eval/samples_per_second</td><td>203.701</td></tr><tr><td>eval/steps_per_second</td><td>12.82</td></tr><tr><td>iteration</td><td>5</td></tr><tr><td>test/accuracy</td><td>0.77867</td></tr><tr><td>test/f1</td><td>0.77851</td></tr><tr><td>test/f1_per_class_mean</td><td>0.77851</td></tr><tr><td>test/loss</td><td>0.63984</td></tr><tr><td>test/precision</td><td>0.78068</td></tr><tr><td>test/precision_per_class_mean</td><td>0.78068</td></tr><tr><td>test/recall</td><td>0.77867</td></tr><tr><td>test/recall_per_class_mean</td><td>0.77867</td></tr><tr><td>test/runtime</td><td>9.3786</td></tr><tr><td>test/samples_per_second</td><td>199.924</td></tr><tr><td>test/steps_per_second</td><td>12.582</td></tr><tr><td>test_accuracy</td><td>0.77867</td></tr><tr><td>test_f1</td><td>0.77851</td></tr><tr><td>test_precision< ...
#  View run <strong style="color:#cdcd00">iteration_5</strong> at: <a href='https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora/runs/ghoi2nxe' target="_blank">https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora/runs/ghoi2nxe</a><br> View project at: <a href='https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora' target="_blank">https://wandb.ai/andretiagosilva77-faculdade-de-engenharia-da-universidad/consumer-complaints-robustness-with-lora</a><br>Synced 5 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20250524_232223-ghoi2nxe/logs</code>
# 💾 New best model saved! Accuracy: 0.7787
# ⭐ This is the new best model!
# ✅ Iteration 5 completed!
#
# ================================================================================
# 📊 FINAL STATISTICAL ROBUSTNESS ANALYSIS
# ================================================================================
#
# 📈 AGGREGATED METRICS ACROSS 5 ITERATIONS:
# ------------------------------------------------------------
# Accuracy    : 0.7667 ± 0.0146 [0.7381 - 0.7787]
# F1          : 0.7660 ± 0.0150 [0.7368 - 0.7785]
# Precision   : 0.7681 ± 0.0157 [0.7373 - 0.7807]
# Recall      : 0.7667 ± 0.0146 [0.7381 - 0.7787]
#
# 📊 INDIVIDUAL ITERATION RESULTS:
# ------------------------------------------------------------
# Iteration  1: Acc=0.7381, F1=0.7368, Prec=0.7373, Rec=0.7381
# Iteration  2: Acc=0.7755, F1=0.7749, Prec=0.7772, Rec=0.7755
# Iteration  3: Acc=0.7712, F1=0.7703, Prec=0.7743, Rec=0.7712
# Iteration  4: Acc=0.7701, F1=0.7695, Prec=0.7708, Rec=0.7701
# Iteration  5: Acc=0.7787, F1=0.7785, Prec=0.7807, Rec=0.7787
#
# ================================================================================
# 🔍 COMPREHENSIVE ERROR ANALYSIS
# ================================================================================
#
# 📊 AGGREGATING ERROR ANALYSIS ACROSS ITERATIONS
# ------------------------------------------------------------
#
# MOST CHALLENGING CLASSIFICATION PAIRS (AGGREGATED):
#    - Debt Collection → Credit Reporting: 364 total errors
#    - Bank Accounts and Services → Credit Card Services: 243 total errors
#    - Credit Card Services → Bank Accounts and Services: 213 total errors
#    - Credit Reporting → Debt Collection: 179 total errors
#    - Credit Card Services → Credit Reporting: 141 total errors
#
# CLASS-WISE ACCURACY SUMMARY:
#    - Debt Collection: 0.6560 ± 0.0294
#    - Credit Card Services: 0.7429 ± 0.0191
#    - Credit Reporting: 0.7840 ± 0.0218
#    - Bank Accounts and Services: 0.7963 ± 0.0090
#    - Loans: 0.8544 ± 0.0152
#
# ✅ Aggregate error analysis saved to ./outputs/error_analysis/aggregate_error_analysis.txt
# ✅ Pipeline completed successfully!
# 📁 Results saved in: ./outputs
# 📈 Check Weights & Biases project: consumer-complaints-robustness-with-lora
# 📊 Visualizations saved as: ./outputs/results_distribution.png
# 🔍 Error analysis saved in: ./outputs/error_analysis/
# 💾 Best model saved in: ./outputs/best_model_overall
#
# ⚖️  CONCLUSION: Model shows MODERATE statistical robustness
